# %% [markdown]
# ### Create database from parquet files in DBFS

# %% [markdown]
# ##### Checking and changing the current Database

# %%
spark.catalog.currentDatabase()
# Out:
# Out[1]: 'default'

# %% [markdown]
# You will now create databases in your workspace.
# To name it correctly, **substitute "renato" by your name in the `username` variable.

# %%
## Put your name here

username = "renato"

dbutils.widgets.text("username", username)
spark.sql(f"CREATE DATABASE IF NOT EXISTS dsacademy_embedded_wave3_{username}")
spark.sql(f"USE dsacademy_embedded_wave3_{username}")

spark.sql("SET spark.databricks.delta.formatCheck.enabled = false")
spark.sql("SET spark.databricks.delta.properties.defaults.autoOptimize.optimizeWrite = true")
# Out:
# Out[2]: DataFrame[key: string, value: string]

# %% [markdown]
# ##### Checking database creation

# %%
spark.sql('SHOW DATABASES').display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>databaseName</th></tr></thead><tbody><tr><td>cashman_ho_fi</td></tr><tr><td>clv</td></tr><tr><td>contact_policy_rbko</td></tr><tr><td>customer_lifetime_value_rbro</td></tr><tr><td>default</td></tr><tr><td>dlt_test</td></tr><tr><td>ds_academy_embedded_wave_3</td></tr><tr><td>dsa_group2</td></tr><tr><td>dsacademy</td></tr><tr><td>dsacademy_embedded_wave3_andras</td></tr><tr><td>dsacademy_embedded_wave3_anita</td></tr><tr><td>dsacademy_embedded_wave3_bernadett</td></tr><tr><td>dsacademy_embedded_wave3_chiara</td></tr><tr><td>dsacademy_embedded_wave3_currentuser</td></tr><tr><td>dsacademy_embedded_wave3_dmytro</td></tr><tr><td>dsacademy_embedded_wave3_egezon</td></tr><tr><td>dsacademy_embedded_wave3_group2_w3</td></tr><tr><td>dsacademy_embedded_wave3_ivona</td></tr><tr><td>dsacademy_embedded_wave3_michael</td></tr><tr><td>dsacademy_embedded_wave3_renato</td></tr><tr><td>dsacademy_embedded_wave3_sorry_renato</td></tr><tr><td>dsacademy_embedded_wave3_test</td></tr><tr><td>dsacademy_embedded_wave3_wzhpoo</td></tr><tr><td>dsacademy_renato</td></tr><tr><td>gdwh_il_exploration_pipeline</td></tr><tr><td>gdwh_test</td></tr><tr><td>gdwhbranch</td></tr><tr><td>ho_norkom</td></tr><tr><td>nbo_microtxsc_rbko</td></tr><tr><td>nbo_rbal</td></tr><tr><td>norkom_alertscoring_ho</td></tr><tr><td>norkom_exploration_pipeline</td></tr><tr><td>ofsa_exploration_ho</td></tr><tr><td>ofsa_exploration_pipeline</td></tr><tr><td>product_sales_campaign_rbi</td></tr><tr><td>rbal_lgd</td></tr><tr><td>rbal_lgd_final</td></tr><tr><td>rbbh_lgd</td></tr><tr><td>rbbh_lgd_2</td></tr><tr><td>rbbh_lgd_3</td></tr><tr><td>rbbhlgd</td></tr><tr><td>rbhu_countly</td></tr><tr><td>rbko_gdwh_il</td></tr><tr><td>rbko_lgd</td></tr><tr><td>rbrs_lgd</td></tr><tr><td>rbrs_pd</td></tr><tr><td>rrmc_cris</td></tr><tr><td>rrmc_dc</td></tr><tr><td>rrmc_joint_modeling_team</td></tr><tr><td>rrmc_lgd</td></tr><tr><td>rrmc_onboarding</td></tr><tr><td>rrmc_pd</td></tr><tr><td>rrmc_rbal</td></tr><tr><td>rrmc_rbal_lgd</td></tr><tr><td>rrmc_rbbh</td></tr><tr><td>rrmc_rbbh_lgd</td></tr><tr><td>rrmc_rbbh_pd</td></tr><tr><td>rrmc_rbhr</td></tr><tr><td>rrmc_rbko</td></tr><tr><td>rrmc_rbrs</td></tr><tr><td>rrmc_showcase</td></tr><tr><td>sesamm</td></tr><tr><td>transactional_scorecards_rbal</td></tr><tr><td>transactional_scorecards_rbko</td></tr><tr><td>wzhanaa</td></tr><tr><td>wzhbsn</td></tr><tr><td>wzhbsn_test</td></tr><tr><td>wzhlje</td></tr></tbody></table></div>

# %% [markdown]
# ##### Checking existing tables

# %%
spark.sql('SHOW TABLES').display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>database</th><th>tableName</th><th>isTemporary</th></tr></thead><tbody><tr><td>dsacademy_embedded_wave3_renato</td><td>data20k</td><td>false</td></tr><tr><td>dsacademy_embedded_wave3_renato</td><td>data40k</td><td>false</td></tr><tr><td>dsacademy_embedded_wave3_renato</td><td>testtable</td><td>false</td></tr></tbody></table></div>

# %% [markdown]
# ##### Checking example parquet files

# %%
# %fs ls
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th><th>name</th><th>size</th><th>modificationTime</th></tr></thead><tbody><tr><td>dbfs:/FileStore/</td><td>FileStore/</td><td>0</td><td>1666957356540</td></tr><tr><td>dbfs:/databricks-datasets/</td><td>databricks-datasets/</td><td>0</td><td>0</td></tr><tr><td>dbfs:/databricks-results/</td><td>databricks-results/</td><td>0</td><td>0</td></tr><tr><td>dbfs:/git-proxy/</td><td>git-proxy/</td><td>0</td><td>1666957356540</td></tr><tr><td>dbfs:/tmp/</td><td>tmp/</td><td>0</td><td>1666957356540</td></tr></tbody></table></div>

# %% [markdown]
# #####Checking inside folder

# %%
# %fs ls dbfs:/databricks-datasets/
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th><th>name</th><th>size</th><th>modificationTime</th></tr></thead><tbody><tr><td>dbfs:/databricks-datasets/COVID/</td><td>COVID/</td><td>0</td><td>1666957357711</td></tr><tr><td>dbfs:/databricks-datasets/README.md</td><td>README.md</td><td>976</td><td>1532502324000</td></tr><tr><td>dbfs:/databricks-datasets/Rdatasets/</td><td>Rdatasets/</td><td>0</td><td>1666957357711</td></tr><tr><td>dbfs:/databricks-datasets/SPARK_README.md</td><td>SPARK_README.md</td><td>3359</td><td>1511905961000</td></tr><tr><td>dbfs:/databricks-datasets/adult/</td><td>adult/</td><td>0</td><td>1666957357711</td></tr><tr><td>dbfs:/databricks-datasets/airlines/</td><td>airlines/</td><td>0</td><td>1666957357711</td></tr><tr><td>dbfs:/databricks-datasets/amazon/</td><td>amazon/</td><td>0</td><td>1666957357711</td></tr><tr><td>dbfs:/databricks-datasets/asa/</td><td>asa/</td><td>0</td><td>1666957357711</td></tr><tr><td>dbfs:/databricks-datasets/atlas_higgs/</td><td>atlas_higgs/</td><td>0</td><td>1666957357711</td></tr><tr><td>dbfs:/databricks-datasets/bikeSharing/</td><td>bikeSharing/</td><td>0</td><td>1666957357711</td></tr><tr><td>dbfs:/databricks-datasets/cctvVideos/</td><td>cctvVideos/</td><td>0</td><td>1666957357711</td></tr><tr><td>dbfs:/databricks-datasets/credit-card-fraud/</td><td>credit-card-fraud/</td><td>0</td><td>1666957357711</td></tr><tr><td>dbfs:/databricks-datasets/cs100/</td><td>cs100/</td><td>0</td><td>1666957357711</td></tr><tr><td>dbfs:/databricks-datasets/cs110x/</td><td>cs110x/</td><td>0</td><td>1666957357711</td></tr><tr><td>dbfs:/databricks-datasets/cs190/</td><td>cs190/</td><td>0</td><td>1666957357711</td></tr><tr><td>dbfs:/databricks-datasets/data.gov/</td><td>data.gov/</td><td>0</td><td>1666957357711</td></tr><tr><td>dbfs:/databricks-datasets/definitive-guide/</td><td>definitive-guide/</td><td>0</td><td>1666957357711</td></tr><tr><td>dbfs:/databricks-datasets/delta-sharing/</td><td>delta-sharing/</td><td>0</td><td>1666957357711</td></tr><tr><td>dbfs:/databricks-datasets/flights/</td><td>flights/</td><td>0</td><td>1666957357711</td></tr><tr><td>dbfs:/databricks-datasets/flower_photos/</td><td>flower_photos/</td><td>0</td><td>1666957357711</td></tr><tr><td>dbfs:/databricks-datasets/flowers/</td><td>flowers/</td><td>0</td><td>1666957357711</td></tr><tr><td>dbfs:/databricks-datasets/genomics/</td><td>genomics/</td><td>0</td><td>1666957357711</td></tr><tr><td>dbfs:/databricks-datasets/hail/</td><td>hail/</td><td>0</td><td>1666957357711</td></tr><tr><td>dbfs:/databricks-datasets/identifying-campaign-effectiveness/</td><td>identifying-campaign-effectiveness/</td><td>0</td><td>1666957357711</td></tr><tr><td>dbfs:/databricks-datasets/iot/</td><td>iot/</td><td>0</td><td>1666957357711</td></tr><tr><td>dbfs:/databricks-datasets/iot-stream/</td><td>iot-stream/</td><td>0</td><td>1666957357711</td></tr><tr><td>dbfs:/databricks-datasets/learning-spark/</td><td>learning-spark/</td><td>0</td><td>1666957357711</td></tr><tr><td>dbfs:/databricks-datasets/learning-spark-v2/</td><td>learning-spark-v2/</td><td>0</td><td>1666957357711</td></tr><tr><td>dbfs:/databricks-datasets/lending-club-loan-stats/</td><td>lending-club-loan-stats/</td><td>0</td><td>1666957357711</td></tr><tr><td>dbfs:/databricks-datasets/med-images/</td><td>med-images/</td><td>0</td><td>1666957357711</td></tr><tr><td>dbfs:/databricks-datasets/media/</td><td>media/</td><td>0</td><td>1666957357711</td></tr><tr><td>dbfs:/databricks-datasets/mnist-digits/</td><td>mnist-digits/</td><td>0</td><td>1666957357711</td></tr><tr><td>dbfs:/databricks-datasets/news20.binary/</td><td>news20.binary/</td><td>0</td><td>1666957357711</td></tr><tr><td>dbfs:/databricks-datasets/nyctaxi/</td><td>nyctaxi/</td><td>0</td><td>1666957357711</td></tr><tr><td>dbfs:/databricks-datasets/nyctaxi-with-zipcodes/</td><td>nyctaxi-with-zipcodes/</td><td>0</td><td>1666957357711</td></tr><tr><td>dbfs:/d ...

# %% [markdown]
# #####Checking inside subfolder

# %%
# %fs ls dbfs:/databricks-datasets/amazon/
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th><th>name</th><th>size</th><th>modificationTime</th></tr></thead><tbody><tr><td>dbfs:/databricks-datasets/amazon/README.md</td><td>README.md</td><td>396</td><td>1511917229000</td></tr><tr><td>dbfs:/databricks-datasets/amazon/data20K/</td><td>data20K/</td><td>0</td><td>1666957358050</td></tr><tr><td>dbfs:/databricks-datasets/amazon/test4K/</td><td>test4K/</td><td>0</td><td>1666957358050</td></tr><tr><td>dbfs:/databricks-datasets/amazon/users/</td><td>users/</td><td>0</td><td>1666957358050</td></tr></tbody></table></div>

# %% [markdown]
# #####Creating a SPARK Dataframe from a Parquet file:

# %%
path = 'dbfs:/databricks-datasets/amazon/data20K/'
df = spark.read.format('parquet').options(header=True,inferSchema=True).load(path)
df.display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>rating</th><th>review</th></tr></thead><tbody><tr><td>4.0</td><td>Worked as expected.I'm not sure what else you expect me to say.  I expected no less.Dunno what else to say.</td></tr><tr><td>5.0</td><td>This mouse is amazing, I had owned a Razer Naga, and a R.A.T. 7 mouse. And I am not afraid to say that this mouse takes the cake, for $20 it looks like its worth $80. The only issue i had was that the seller sent me a wireless version, but I don't mind because it works just as well. Also where you see silver on the mouse in reality it is glossy black, and the mouse looks better IRL then in the pictures. I will add on to this review in a month or so to check in.</td></tr><tr><td>4.0</td><td>we recently had a baby boy so now the use of my home theater system is on the shelf for awhile.  My wife also is not into big sound so decided to try out these wireless headphones.  at first i almost sent them back because i took the easy route and hooked them into my receivers headphone jack.  The sound was terrible and there was the dreaded hissing noise you get with some wireless electronics.  before packing them up i decided to hook them up into the jacks on the TV. Difference was like night and day.  the sound quality is great and really brings out some of the background sounds and music that you typically don't notice unless you are in a movie theater.  They aren't super comfortable for long durations but that can be expected with most headphones.  these come fully recommended.</td></tr><tr><td>3.0</td><td>Works good for a boy of 6 and his parents.This game is not really requiring any skills (be it game skills, memory or else). It is still fun but gets repetitive fast. Said that, my son still enjoyed it enough to want a proper "adult" Catan.</td></tr><tr><td>2.0</td><td>Fabric is nice and soft but zipper broke the first time we used it. Very disappointing. The fit was fine, so we still use it to get our monies worth</td></tr><tr><td>4.0</td><td>They are screws with square heads, what else do you need to know.  They work, they hold two pieces of wood together.</td></tr><tr><td>5.0</td><td>I love this prolduct and the other items that go with it.  Bath and Body dropped this scent so I as thrilled find that I could still purchase it.</td></tr><tr><td>3.0</td><td>This is an ok pump.  It has the nice bracket that can mount to your bike and you have it for the road.And although the image here doesn't show it, it does have the gauge, though it isn't the most accurate gauge (not really a problem when the tire is rated for 55 to 100 PSI).Much like one other reviewer noted, the instructions on how to switch from Schrader to Presta are not very clear and should be researched before fumbling with this blasted thing for hours trying to make it work.And like the title mentions, this isn't as tiny as the MINI name implies.  When looking for a place to mount it on my bike, I am really running short on ideas.  The obvious places would interfere with pedaling.All that said, it puts air in the tire.  Slowly.  It is double action, but the throw isn't very much.  And the higher the pressure, the more difficult it is to pump.</td></tr><tr><td>5.0</td><td>Perfect for the gym or under a few layers for the chilly morning runs. I own quite a few, and just can't get enough!</td></tr><tr><td>4.0</td><td>I'd hoped my 2 year old kitty would have been more enthusiastic about these little Chew Mice, but perhaps she has too many other toys.  All-in-all, they're a good addition to her toy collection.</td></tr><tr><td>5.0</td><td>This had some assembling but overall it is a great product!!! I am a Youtuber and when I make car vlogs it is hard to find a good spot to place my ipod but now I just put this car mount on my windshield and attach my ipod and I am good to go! It also comes with a dashboard mount, but I haven't tinkered with it yet...</td></tr><t ...

# %% [markdown]
# ##### Create tables from Parquet files in DBFS

# %%
# %sql
CREATE TABLE IF NOT EXISTS data20k USING parquet OPTIONS (path "dbfs:/databricks-datasets/amazon/data20K/");
CREATE TABLE IF NOT EXISTS data40k USING parquet OPTIONS (path "dbfs:/databricks-datasets/amazon/test4K/");
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>

# %% [markdown]
# ##### Checking tables creation
#
# You can also use the **data** tab of the workspace UI to confirm your tables were created.

# %%
spark.sql('SHOW TABLES').display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>database</th><th>tableName</th><th>isTemporary</th></tr></thead><tbody><tr><td>dsacademy_embedded_wave3_renato</td><td>data20k</td><td>false</td></tr><tr><td>dsacademy_embedded_wave3_renato</td><td>data40k</td><td>false</td></tr><tr><td>dsacademy_embedded_wave3_renato</td><td>testtable</td><td>false</td></tr></tbody></table></div>

# %% [markdown]
# ### Execute SQL to explore the newly created datasets
# Run SQL queries on the `data20k`, and `data40k` tables to answer the following questions.
# - How many brands are available for purchasing at Amazon?
# - What is the average rating for brand Greenies?
# - Which brand has the highest average price?

# %% [markdown]
# #### Q1: What brands are available for purchasing at Amazon?
#
# We can inspect the structure of the **`data40k`** dataset.

# %%
# %sql 
DESCRIBE data40k;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>col_name</th><th>data_type</th><th>comment</th></tr></thead><tbody><tr><td>asin</td><td>string</td><td>null</td></tr><tr><td>brand</td><td>string</td><td>null</td></tr><tr><td>helpful</td><td>array<bigint></td><td>null</td></tr><tr><td>img</td><td>string</td><td>null</td></tr><tr><td>price</td><td>double</td><td>null</td></tr><tr><td>rating</td><td>double</td><td>null</td></tr><tr><td>review</td><td>string</td><td>null</td></tr><tr><td>time</td><td>bigint</td><td>null</td></tr><tr><td>title</td><td>string</td><td>null</td></tr><tr><td>user</td><td>string</td><td>null</td></tr></tbody></table></div>

# %%
# %sql 
SELECT * FROM data40k LIMIT 100;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>asin</th><th>brand</th><th>helpful</th><th>img</th><th>price</th><th>rating</th><th>review</th><th>time</th><th>title</th><th>user</th></tr></thead><tbody><tr><td>B00014JKG0</td><td>Nature&#39;s Gate</td><td>List(0, 0)</td><td>http://ecx.images-amazon.com/images/I/31RIumF2GIL._SY300_.jpg</td><td>10.02</td><td>5.0</td><td>I bought this for my gf and she loves it. Unlike other lotions you don't need several coats for dry shin and it smells nice too. The oils leave her skin smooth for a whole day not just an hr or 2. I'd recommend this to anyone with any skin type, you can't go wrong with this stuff and I'll be ordering more when it runs out.</td><td>1339372800</td><td>Nature's Gate Tea Tree Moisturizing Lotion for Irritated, Distressed Skin, 18-Ounce Pump Bottle</td><td>A1E57U9XDQCSKC</td></tr><tr><td>B000L596FE</td><td>Luxor Pro</td><td>List(0, 0)</td><td>http://ecx.images-amazon.com/images/I/41xj70ovtmL._SY300_.jpg</td><td>8.97</td><td>5.0</td><td>My 5 yr old wakes up with terribly knotted hair & this brush glides right through it. It truly is some kind of magic! I'd love to give these brushes out as party favors for her birthday :-)</td><td>1388620800</td><td>The Wet Brush Detangling Shower Brush, Colors Vary</td><td>AO95JTORR64XZ</td></tr><tr><td>B008FXKOI2</td><td>Greenies</td><td>List(2, 2)</td><td>http://ecx.images-amazon.com/images/I/51ocmMt8tfL._SY300_.jpg</td><td>4.72</td><td>4.0</td><td>A healthier choice than the Friskies line for kitty crunchies.  My vet uses this brand, which is why I switched.I alternate between the chicken skin & fur and the salmon hairball control, depending on what kind of dry food currently in use.  These smartbites are easier for my cat to chew than the dental ones, though I will use the dental every other month or so.Only negative: the volume seems less than from a year ago on the smartbites, but that's in the brick & mortar stores, also.</td><td>1385856000</td><td>Greenies Smartbites Cat Treats, 2.1-Ounce</td><td>AKLVHFSQRFQL7</td></tr><tr><td>B000UJW676</td><td>Nelson</td><td>List(2, 2)</td><td>http://ecx.images-amazon.com/images/I/51M2elTqCpL._SY300_.jpg</td><td>6.39</td><td>1.0</td><td>Item fell short of expectations, it did not fit my 3/4&#34; hose as it stated it would and that is why I purchased it</td><td>1376092800</td><td>Nelson Brass/Metal Hose Repair Clamp Connector Female 50521</td><td>A13KOZOGKOF5R4</td></tr><tr><td>B004TK0IG8</td><td>Stanley</td><td>List(0, 0)</td><td>http://ecx.images-amazon.com/images/I/41OpTlmDsKL._SX300_.jpg</td><td>99.99</td><td>4.0</td><td>It took much work to flatten the backs of the larger (1&#34; and 3/4&#34;) chisels.  The 1&#34; chisel has a major grinding flaw near the socket, but not worth returning, since I only needed to flatten the first inch or so to get a good polish. These stay sharp longer than my Irwin chisels, but no where near as long as my Veritas chisels, but the price was right for the set. Once flattened and honed, they are a pleasure to use. These chisels are well balanced easy to hold with just the fingers.I can't compare them to L.N. since I don't own any.  Great chisels for a serious hobbyist.</td><td>1355443200</td><td>Stanley 16-791 Sweetheart 750 Series Socket Chisel 4 Piece Set</td><td>A19RQK364II90W</td></tr><tr><td>B00D12OBEU</td><td>MSI</td><td>List(1, 1)</td><td>http://ecx.images-amazon.com/images/I/51X0FrnHE6L._SX300_.jpg</td><td>150.23</td><td>2.0</td><td>I have one sata HDD. I bought an SSD and my motherboard sometimes doesn't recognize it, only the first HDD. Today I bought one optical drive and I've gotten the same problem.In brief, this motherboard does not work good with two sata devices.If I would had known this I would have bought an asus rampagePD: I updated bios and nothing.</td><td>1393632000</td><td>MSI Computer Corp. Motherboard ATX DDR3 1333 LGA 1150 Motherboards Z87-G45 GAMING</td><td>A30X ...

# %%
# %sql 
-- ANSWER
SELECT COUNT(DISTINCT(brand)) FROM data40k;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>count(DISTINCT brand)</th></tr></thead><tbody><tr><td>2563</td></tr></tbody></table></div>

# %% [markdown]
# #### Q2: What is the average rating for brand Greenies?

# %%
# %sql
-- ANSWER
SELECT AVG(rating)
FROM data40k
WHERE brand = 'Greenies';
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>avg(rating)</th></tr></thead><tbody><tr><td>4.0</td></tr></tbody></table></div>

# %% [markdown]
# #### Q3: Which brand has the highest average price?

# %%
# %sql
-- ANSWER
SELECT brand, AVG(price) as avg_price
FROM data40k
GROUP BY brand
ORDER BY avg_price
DESC;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>brand</th><th>avg_price</th></tr></thead><tbody><tr><td>BAK</td><td>889.88</td></tr><tr><td>Bell&#39;O</td><td>877.17</td></tr><tr><td>Bayou Fitness</td><td>817.0</td></tr><tr><td>Blast Zone</td><td>749.99</td></tr><tr><td>Tissot</td><td>725.0</td></tr><tr><td>Kenwood</td><td>709.94</td></tr><tr><td>Toto</td><td>658.145</td></tr><tr><td>Quantum</td><td>624.0</td></tr><tr><td>Shop Fox</td><td>599.0</td></tr><tr><td>Miele</td><td>583.0</td></tr><tr><td>Boraam</td><td>554.99</td></tr><tr><td>Citizen</td><td>525.625</td></tr><tr><td>Minka Aire</td><td>524.95</td></tr><tr><td>Supermicro</td><td>512.9</td></tr><tr><td>pal</td><td>500.0</td></tr><tr><td>Tamron</td><td>499.0</td></tr><tr><td>Ecosmart</td><td>494.98</td></tr><tr><td>Azden</td><td>493.93999999999994</td></tr><tr><td>Sharp</td><td>489.99</td></tr><tr><td>Vitalizer Plus</td><td>485.0</td></tr><tr><td>Polycom</td><td>472.93</td></tr><tr><td>Wise</td><td>470.5</td></tr><tr><td>Global Parts</td><td>454.89</td></tr><tr><td>Home Styles</td><td>446.75</td></tr><tr><td>Fujitsu</td><td>445.94</td></tr><tr><td>Vanguard</td><td>429.99</td></tr><tr><td>Little Giant Ladders</td><td>399.8</td></tr><tr><td>Energy</td><td>398.0</td></tr><tr><td>Dorel Asia</td><td>393.99</td></tr><tr><td>Vitamix</td><td>378.95</td></tr><tr><td>Sonos</td><td>370.99</td></tr><tr><td>Neato Robotics</td><td>369.99</td></tr><tr><td>Techcraft</td><td>366.0</td></tr><tr><td>Tike Tech</td><td>359.99</td></tr><tr><td>Fujifilm</td><td>353.83000000000004</td></tr><tr><td>Sun&amp;#45;Mar</td><td>349.99</td></tr><tr><td>Total Gym</td><td>344.45</td></tr><tr><td>Baxton Studio</td><td>337.32</td></tr><tr><td>Walker Edison</td><td>336.29</td></tr><tr><td>Schauer</td><td>332.89</td></tr><tr><td>Rhino Rack</td><td>332.1</td></tr><tr><td>Leggett &amp; Platt Fashion Bed Group</td><td>329.0</td></tr><tr><td>Swagman Bicycle Carriers</td><td>323.78</td></tr><tr><td>Beretta</td><td>312.8</td></tr><tr><td>ComforTrac</td><td>310.0</td></tr><tr><td>Jet</td><td>306.66</td></tr><tr><td>Bazzaz Performance</td><td>303.86</td></tr><tr><td>Kraus</td><td>299.95</td></tr><tr><td>Bowflex</td><td>299.0</td></tr><tr><td>Nespresso</td><td>290.0</td></tr><tr><td>Pioneer</td><td>289.0</td></tr><tr><td>Signature Sleep</td><td>285.0</td></tr><tr><td>Cricut</td><td>279.95</td></tr><tr><td>Tripp Lite</td><td>276.995</td></tr><tr><td>NOVA</td><td>275.19</td></tr><tr><td>Keratin Complex</td><td>260.98</td></tr><tr><td>Bulova</td><td>259.17</td></tr><tr><td>Kiddy</td><td>257.65</td></tr><tr><td>Radiancy</td><td>255.0</td></tr><tr><td>Dell</td><td>252.06</td></tr><tr><td>Kolpin</td><td>250.1</td></tr><tr><td>Campfire In A Can</td><td>249.99</td></tr><tr><td>blu</td><td>245.85</td></tr><tr><td>Nutrimill</td><td>241.33</td></tr><tr><td>Sunny Health &amp; Fitness</td><td>241.15</td></tr><tr><td>GTC</td><td>240.72</td></tr><tr><td>Masterbuilt</td><td>238.97</td></tr><tr><td>Panasonic</td><td>238.19789473684207</td></tr><tr><td>Hayward</td><td>236.37000000000003</td></tr><tr><td>Wilson Electronics</td><td>235.0</td></tr><tr><td>Calphalon</td><td>234.99</td></tr><tr><td>DaVinci</td><td>234.0</td></tr><tr><td>Breville</td><td>232.67</td></tr><tr><td>ACME</td><td>232.28</td></tr><tr><td>Westin</td><td>230.21</td></tr><tr><td>Keekaroo</td><td>229.95</td></tr><tr><td>Merry</td><td>225.46</td></tr><tr><td>Singer</td><td>224.67</td></tr><tr><td>Dyna-Glo</td><td>222.0</td></tr><tr><td>Yakima</td><td>219.0</td></tr><tr><td>Uttermost</td><td>217.8</td></tr><tr><td>Razor</td><td>213.98000000000002</td></tr><tr><td>Makita</td><td>213.37333333333333</td></tr><tr><td>Delta</td><td>210.99</td></tr><tr><td>Acer</td><td>209.8</td></tr><tr><td>DEWALT</td><td>209.358</td></tr><tr><td>GV</td><td>208.99</td></tr><tr><td>ViewSonic</td><td>208.12</td></tr><tr><td>Bestop</td><td>205.99</td></tr><tr><td>Koblenz</td><td>205.0</td></tr><tr><td>Apple</td><td>204.92538 ...

# %% [markdown]
# You can always use the _sqldf variable that stires the result of the last query in a Spark dataframe.

# %%
# _sqldf.display()
_sqldf.show()
# Out:
# +--------------+------------------+
# |         brand|         avg_price|
# +--------------+------------------+
# |           BAK|            889.88|
# |    Bell&#39;O|            877.17|
# | Bayou Fitness|             817.0|
# |    Blast Zone|            749.99|
# |        Tissot|             725.0|
# |       Kenwood|            709.94|
# |          Toto|           658.145|
# |       Quantum|             624.0|
# |      Shop Fox|             599.0|
# |         Miele|             583.0|
# |        Boraam|            554.99|
# |       Citizen|           525.625|
# |    Minka Aire|            524.95|
# |    Supermicro|             512.9|
# |           pal|             500.0|
# |        Tamron|             499.0|
# |      Ecosmart|            494.98|
# |         Azden|493.93999999999994|
# |         Sharp|            489.99|
# |Vitalizer Plus|             485.0|
# +--------------+------------------+
# only showing top 20 rows

# %% [markdown]
# #### Now it's you turn!
#
# Run SQL queries on the data40k tables to answer the following questions.
#
# + Which brand has more reviews with the word "love"?
# + Is it reasonable to expect that more expensive products receive more ratings? And more positive ratings? Answer this using visualizations.
# + Which brand has the most helpful reviews?

# %%
# %sql
-- ANSWER

# %%
# %sql
-- ANSWER

# %%
# %sql
-- ANSWER
